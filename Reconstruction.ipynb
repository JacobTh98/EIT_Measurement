# %%
import lobi as lb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import imageio
import reconstruction 
import os

# %% [markdown]
# ## Rekonstruktion
# - [Index](index.ipynb)

# %%
Dir = 'Zylinder P(0.5,0)'

# %% [markdown]
# # Inhalt:
#  - Info.txt ausgeben
#  - Darstellen Groundtruth
#  - Mittelwertbild
#  - Gif der Messwerte

# %%
lb.view_txt(Dir)
# Out:
# EIT-Messung
# ----------------------------------
# Datum: 	 	 	09.03.2022
# Uhrzeit: 	 	11:02 Uhr
# Messmodus: 	 	d
# Elektrodenanzahl: 	16
# Schunk Step Intevall 	5	[°/step]
# Leitfähigkeit 	 	1	[mS]
# Raumtemperatur 	 	20	[°C]
#
# Wasserstand 	 	33	[mm]
# Sonstige Informationen:
#  -Keine weiteren Angaben

# %%
lb.view_GrTr(Dir)

# %%
lb.single_reconstruction(16,Dir,135, BackProj=True,diff_img=False)
# Out:
# Minimaler Wert:  -9.462499999999999
# Maximaler Wert:  13.0125
# Δ Permittivität:  22.474999999999998

# %%
NameGif = 'DreieckStandart'
lb.gif_reconstruction(Dir, full = False,NameGif=NameGif,diff_img=False ,kind_of='raw')
# Out:
# Elektrodenanzahl aus info.txt:	 16
# Step-Intervalle aus info.txt:	 5

# %%
lb.show_gif(NameGif)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Der Threadmodus kann nicht nach dem Einstellen geändert werden
#   warnings.warn(str(err))

# %%
IMGs = np.load('Dreieck_standart/0m_m.npy')

# %% [markdown]
# interpolation : str, default: :rc:`image.interpolation`
#     The interpolation method used.
#
#     Supported values are 'none', 'antialiased', 'nearest', 'bilinear',
#     'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite',
#     'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell',
#     'sinc', 'lanczos', 'blackman'.

# %%
plt.figure(figsize=(20,12))
plt.imshow(IMGs, interpolation='none')

# %%
import lobi as lb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import imageio
import reconstruction 
import os

# %% [markdown]
# ## Rekonstruktion
# - [Index](index.ipynb)

# %%
Dir = 'Dreieck_standart'

# %% [markdown]
# # Inhalt:
#  - Info.txt ausgeben
#  - Darstellen Groundtruth
#  - Mittelwertbild
#  - Gif der Messwerte

# %%
lb.view_txt(Dir)
# Out:
# EIT-Messung
# ----------------------------------
# Datum: 			09.02.2022
# Uhrzeit:		09:45 Uhr
# Messmodus: 		e
# Elektrodenanzahl: 	16
# Schunk Step Intevall 	5	[°/step]
# Leitfähigkeit		15 	[mS]
# Wasserstand 		33   	[mm]
# Raumtemperatur 		20°C	[°C]
#
# Sonstige Informationen:
#  -Keine weiteren Angaben

# %%
lb.view_GrTr(Dir)

# %%
lb.single_reconstruction(16,Dir,0,diff_img=False)
# Out:
# Minimaler Wert:  -13.140625000000002
# Maximaler Wert:  5.237499999999999
# Δ Permittivität:  18.378125

# %%
NameGif = 'DreieckStandart'
lb.gif_reconstruction(Dir,5,NameGif=NameGif,diff_img=False ,kind_of='raw')
# Out:
# Elektrodenanzahl aus info.txt:	 16

# %%
lb.show_gif(NameGif)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Der Threadmodus kann nicht nach dem Einstellen geändert werden
#   warnings.warn(str(err))

# %%
import lobi as lb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import imageio
import reconstruction 
import os

# %% [markdown]
# ## Rekonstruktion
# - [Index](index.ipynb)

# %%
Dir = 'Dreieck_standart'

# %% [markdown]
# # Inhalt:
#  - Info.txt ausgeben
#  - Darstellen Groundtruth
#  - Mittelwertbild
#  - Gif der Messwerte

# %%
lb.view_txt(Dir)
# Out:
# EIT-Messung
# ----------------------------------
# Datum: 			09.02.2022
# Uhrzeit:		09:45 Uhr
# Messmodus: 		e
# Elektrodenanzahl: 	16
# Schunk Step Intevall 	5	[°/step]
# Leitfähigkeit		15 	[mS]
# Wasserstand 		33   	[mm]
# Raumtemperatur 		20°C	[°C]
#
# Sonstige Informationen:
#  -Keine weiteren Angaben

# %%
lb.view_GrTr(Dir)

# %%
lb.single_reconstruction(16,Dir,180, BackProj=False,diff_img=False)
# Out:
# completed jac reset
# baselining
# Minimaler Wert:  -2.5530921767540815
# Maximaler Wert:  2.663324146811559
# Δ Permittivität:  5.216416323565641

# %%
NameGif = 'DreieckStand_vor'
lb.gif_reconstruction(Dir, full = False, NameGif=NameGif, BackProj=False,diff_img=True,kind_of='raw')
# Out:
# Elektrodenanzahl aus info.txt:	 16
# Step-Intervalle aus info.txt:	 5
# completed jac reset
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# baselining
# ...

# %%
lb.show_gif(NameGif)
# Out:
# UsageError: Line magic function `%matplot` not found.

# %%
IMGs = np.load(Dir+'/0raw.npy')

# %% [markdown]
# interpolation : str, default: :rc:`image.interpolation`
#     The interpolation method used.
#
#     Supported values are 'none', 'antialiased', 'nearest', 'bilinear',
#     'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite',
#     'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell',
#     'sinc', 'lanczos', 'blackman'.

# %%
plt.figure(figsize=(20,12))
plt.imshow(IMGs, interpolation='none')
